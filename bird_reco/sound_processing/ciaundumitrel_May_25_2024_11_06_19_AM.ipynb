# %%
 # !pip install pydub xenopy librosa numpy noisereduce

# %%
# !pip install tensorflow==2.11.0 tensorflow-io==0.31.0 matplotlib

# %%
import os
import numpy as np
import librosa
import os

from pydub.silence import split_on_silence
from scipy.io import wavfile
import noisereduce as nr

import pydub
from pydub.exceptions import CouldntDecodeError

from xenopy import Query

birds = ["Common Buzzard", "Mallard", "Mute Swan", "Great Tit",  "Hooded Crow", "Grey Heron", "Common Chaffinch",
         "Black-headed Gull", "Great Cormorant", "White Wagtail", "Eurasian Coot",
         "White Stork", "House Sparrow", "Great Egret", "Eurasian Jay", "Eurasian Magpie", "Rook",
         "Western Marsh Harrier", "Fieldfare", "Eurasian Tree Sparrow"]
#
dir_for_birds = dict()

for bird in birds:
    dir_for_birds[bird] = str(bird).strip().replace(" ", '')

def to_wav(bird, path):
    bird_dir = os.path.join(path,'..', 'sounds', bird)
    bird_dir_sounds = os.path.join(bird_dir, dir_for_birds[bird])
    converted_files = []
    os.chdir(bird_dir_sounds)
    delete_wavs = False
    print("recycling old stuff")

    for file in os.listdir(bird_dir_sounds):
        if '.wav' in file:
            if not delete_wavs:
                print(f"Do you want to delete all the .wav files inside {bird_dir_sounds} ?")
                delete_wavs = bool(int(input("1/0")))
            if delete_wavs:
                os.remove(file)

    print("writing .wav files")
    failed_files = []

    for file in os.listdir(bird_dir_sounds):
        mp3_file_path = os.path.join(os.getcwd(), file)  # Construct the full file path
        print(file)
        try:
            if '.mp3' in mp3_file_path:
                sound = pydub.AudioSegment.from_mp3(mp3_file_path)  # Load the MP3 file
                sound.export(f"{file.split('.')[0]}.wav", bitrate=16000, format="wav", )
                converted_files.append(file)
        except CouldntDecodeError as e:
            failed_files.append(file)

    print('failed for: ', failed_files)

    for file in failed_files:
        try:
            mp3_file_path = os.path.join(os.getcwd(), file)  # Construct the full file path
            sound = pydub.AudioSegment.from_file(mp3_file_path, format='mp4')  # Load the MP3 file
            sound.export(f"{file.split('.')[0]}.wav", format="wav")
            converted_files.append(file)
        except:
            pass

    print('deleting old mp3 files')

    for file in converted_files:
        os.remove(file)

    os.chdir(path)


def reduce_noise_(directory, sound_name, save_to):
    sound_path = directory + '/' + sound_name
    rate, data = wavfile.read(sound_path)

    # Check if audio is stereo
    if len(data.shape) == 2 and data.shape[1] == 2:
        # If already stereo, reshape it properly
        data = np.transpose(data)
    else:
        # If mono, duplicate the channel
        data = np.stack((data, data))

    # Reduce noise
    reduced_noise = nr.reduce_noise(y=data, sr=rate, stationary=True)

    # Save the reduced noise audio
    reduced_file_name = fr"{save_to}\{sound_name.split('.')[0]}_reduced.wav"
    wavfile.write(reduced_file_name, rate, reduced_noise.T)  # Transpose back to original shape
    return reduced_file_name


def split_bird(bird, path):
    bird_dir = os.path.join(path,'..', 'sounds', bird)
    bird_dir_sounds = os.path.join(bird_dir, f"{dir_for_birds[bird]}_reduced")
    os.chdir(bird_dir)
    try:
        os.mkdir('splits')
    except FileExistsError as e:
        pass
    file_count = 0
    for file in os.listdir(bird_dir_sounds):
        if file_count > 300:
            os.chdir(path)
            return 
        
        splits = split(file, f"{bird_dir_sounds}\\")
        print(len(splits), f" from {file}")
        save_slips(bird, splits, file_count)
        file_count += len(splits)
    os.chdir(path)


def split(file, path):
    print(file)
    sound = pydub.AudioSegment.from_file(path + file)
    chunks = split_on_silence(
        sound,
        min_silence_len=500,
        silence_thresh=sound.dBFS - 16,
        keep_silence=250
    )
    return chunks


def save_slips(bird_name, splits, file_count):
    export_path = os.path.join('.', 'splits')
    for _, split in enumerate(splits):
        split.export(f"{export_path}/{bird_name.split('.')[0]}_{file_count}.wav", format="wav", bitrate='16k')
        file_count += 1


def reduce_bird(bird, path):

    bird_dir = os.path.join(path,'..', 'sounds', bird)
    os.chdir(bird_dir)
    try:
      bird_dir_sounds = os.path.join(dir_for_birds[bird])
      reduced_dir_name = f"{dir_for_birds[bird]}_reduced"
    except:
      os.chdir(path)
      return

    try:
        os.mkdir(f"{reduced_dir_name}")
    except FileExistsError as e:
        print(e)

    reduced_dir = os.path.join(bird_dir, f"{reduced_dir_name}")

    for file in os.listdir(bird_dir_sounds):
        reduce_noise_(directory=bird_dir_sounds, sound_name=file, save_to=reduced_dir)

    os.chdir(path)


def download_sounds(birds):
    for bird_name in birds:
        q = Query(name=bird_name, q_gt="B", since="2023-06-01")
        # print(metafiles['recordings'])
        try:
            q.retrieve_recordings(multiprocess=False, nproc=5, attempts=5, outdir=f"../sounds/{bird_name}")
        except Exception as e:
            print(e)

if __name__ == "__main__":
    download_sounds(birds)
    for bird in birds:
        to_wav(bird, os.getcwd())
        reduce_bird(bird, os.getcwd())
        split_bird(bird, os.getcwd())
# Out:
# query: Common Buzzard q_gt:B since:2023-06-01
# ... retrieving metadata ...
# process 16592: 100%|██████████| 43/43 [00:42<00:00,  1.02it/s]
# query: Mallard q_gt:B since:2023-06-01
# ... retrieving metadata ...
# process 16592: 100%|██████████| 32/32 [00:37<00:00,  1.17s/it]
# query: Mute Swan q_gt:B since:2023-06-01
# ... retrieving metadata ...
# process 16592: 100%|██████████| 43/43 [00:33<00:00,  1.29it/s]
# query: Great Tit q_gt:B since:2023-06-01
# ... retrieving metadata ...
# process 16592: 100%|█████████▉| 267/268 [05:39<00:00,  1.10it/s]
# Bad url: https://xeno-canto.org/806787/download
# process 16592: 100%|██████████| 268/268 [05:40<00:00,  1.27s/it]
# query: Hooded Crow q_gt:B since:2023-06-01
# ... retrieving metadata ...
# process 16592: 100%|██████████| 165/165 [03:49<00:00,  1.39s/it]
# query: Grey Heron q_gt:B since:2023-06-01
# ... retrieving metadata ...
# process 16592: 100%|██████████| 62/62 [00:51<00:00,  1.21it/s]
# query: Common Chaffinch q_gt:B since:2023-06-01
# ... retrieving metadata ...
# process 16592:   8%|▊         | 21/262 [00:29<06:54,  1.72s/it]
# Bad url: https://xeno-canto.org/905325/download
# process 16592:   8%|▊         | 22/262 [00:30<05:57,  1.49s/it]
# Bad url: https://xeno-canto.org/905323/download
# process 16592:   9%|▉         | 23/262 [00:31<05:22,  1.35s/it]
# Bad url: https://xeno-canto.org/905322/download
# process 16592: 100%|██████████| 262/262 [05:48<00:00,  1.33s/it]
# query: Black-headed Gull q_gt:B since:2023-06-01
# ... retrieving metadata ...
# process 16592: 100%|██████████| 58/58 [00:58<00:00,  1.01s/it]
# query: Great Cormorant q_gt:B since:2023-06-01
# ... retrieving metadata ...
# process 16592: 100%|██████████| 11/11 [00:08<00:00,  1.24it/s]
# query: White Wagtail q_gt:B since:2023-06-01
# ... retrieving metadata ...
# process 16592: 100%|██████████| 65/65 [00:58<00:00,  1.11it/s]
# query: Eurasian Coot q_gt:B since:2023-06-01
# ... retrieving metadata ...
# process 16592: 100%|██████████| 171/171 [02:04<00:00,  1.37it/s]
# query: White Stork q_gt:B since:2023-06-01
# ... retrieving metadata ...
# process 16592: 100%|██████████| 19/19 [00:16<00:00,  1.18it/s]
# query: House Sparrow q_gt:B since:2023-06-01
# ... retrieving metadata ...
# process 16592: 100%|██████████| 118/118 [02:08<00:00,  1.09s/it]
# query: Great Egret q_gt:B since:2023-06-01
# ... retrieving metadata ...
# process 16592: 100%|██████████| 11/11 [00:07<00:00,  1.39it/s]
# query: Eurasian Jay q_gt:B since:2023-06-01
# ... retrieving metadata ...
# process 16592: 100%|██████████| 92/92 [01:15<00:00,  1.22it/s]
# query: Eurasian Magpie q_gt:B since:2023-06-01
# ... retrieving metadata ...
# process 16592: 100%|██████████| 70/70 [01:09<00:00,  1.01it/s]
# query: Rook q_gt:B since:2023-06-01
# ... retrieving metadata ...
# process 16592: 100%|██████████| 31/31 [00:41<00:00,  1.34s/it]
# query: Western Marsh Harrier q_gt:B since:2023-06-01
# ... retrieving metadata ...
# process 16592: 100%|██████████| 11/11 [00:15<00:00,  1.39s/it]
# query: Fieldfare q_gt:B since:2023-06-01
# ... retrieving metadata ...
# process 16592: 100%|██████████| 23/23 [00:23<00:00,  1.03s/it]
# query: Eurasian Tree Sparrow q_gt:B since:2023-06-01
# ... retrieving metadata ...
# process 16592: 100%|██████████| 53/53 [00:47<00:00,  1.12it/s]
# recycling old stuff
# writing .wav files
# 809061.mp3
# 810548.mp3
# 812485.mp3
# 814444.mp3
# 815852.mp3
# 815861.mp3
# 818538.mp3
# 818696.mp3
# 818698.mp3
# 818828.mp3
# 822397.mp3
# 822398.mp3
# 822399.mp3
# 823860.mp3
# 826457.mp3
# 826462.mp3
# 827008.mp3
# 835184.mp3
# 837632.mp3
# 838796.mp3
# 839246.mp3
# 839247.mp3
# 841724.mp3
# 845010.mp3
# 855270.mp3
# 860503.mp3
# 862506.mp3
# 862509.mp3
# 862718.mp3
# 862720.mp3
# 863949.mp3
# 863950.mp3
# 864277.mp3
# 870655.mp3
# 871119.mp3
# 871602.mp3
# 872338.mp3
# 878780.mp3
# 884699.mp3
# 891011.mp3
# 895029.mp3
# 895030.mp3
# 902906.mp3
# failed for:  []
# deleting old mp3 files
# C:\dumi\bird_reco\.venv\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=384
#   warnings.warn(
# C:\dumi\bird_reco\.venv\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=768
#   warnings.warn(
# 809061_reduced.wav
# 1  from 809061_reduced.wav
# 810548_reduced.wav
# 1  from 810548_reduced.wav
# 812485_reduced.wav
# 42  from 812485_reduced.wav
# 814444_reduced.wav
# 1  from 814444_reduced.wav
# 815852_reduced.wav
# 1  from 815852_reduced.wav
# 815861_reduced.wav
# 1  from 815861_reduced.wav
# 818538_reduced.wav
# 6  from 818538_reduced.wav
# 818696_reduced.wav
# 6  from 818696_reduced.wav
# 818698_reduced.wav
# 27  from 818698_reduced.wav
# 818828_reduced.wav
# 28  from 818828_reduced.wav
# 822397_reduced.wav
# 2  from 822397_reduced.wav
# 822398_reduced.wav
# 9  from 822398_reduced.wav
# 822399_reduced.wav
# 1  from 822399_reduced.wav
# 823860_reduced.wav
# 1  from 823860_reduced.wav
# 826457_reduced.wav
# 17  from 826457_reduced.wav
# 826462_reduced.wav
# 45  from 826462_reduced.wav
# 827008_reduced.wav
# 2  from 827008_reduced.wav
# 835184_reduced.wav
# 3  from 835184_reduced.wav
# 837632_reduced.wav
# 14  from 837632_reduced.wav
# 838796_reduced.wav
# 1  from 838796_reduced.wav
# 839246_reduced.wav
# 1  from 839246_reduced.wav
# 839247_reduced.wav
# 1  from 839247_reduced.wav
# 841724_reduced.wav
# 7  from 841724_reduced.wav
# 845010_reduced.wav
# 1  from 845010_reduced.wav
# 855270_reduced.wav
# 5  from 855270_reduced.wav
# 860503_reduced.wav
# 11  from 860503_reduced.wav
# 862506_reduced.wav
# 8  from 862506_reduced.wav
# 862509_reduced.wav
# 89  from 862509_reduced.wav
# recycling old stuff
# writing .wav files
# 813078.mp3
# 827691.mp3
# 831436.mp3
# 838988.mp3
# 840246.mp3
# 844667.mp3
# 844759.mp3
# 844760.mp3
# 863472.mp3
# 870822.mp3
# 871057.mp3
# 871469.mp3
# 871637.mp3
# 871707.mp3
# 871708.mp3
# 872431.mp3
# 876460.mp3
# 877850.mp3
# 878872.mp3
# 881155.mp3
# 883873.mp3
# 884361.mp3
# 893489.mp3
# 894038.mp3
# 894472.mp3
# 895049.mp3
# 895050.mp3
# 897220.mp3
# 900233.mp3
# 900234.mp3
# 902068.mp3
# 906162.mp3
# failed for:  ['863472.mp3', '871637.mp3', '881155.mp3', '884361.mp3', '894038.mp3']
# deleting old mp3 files
# C:\Users\ciaun\AppData\Local\Temp\ipykernel_16592\1178939392.py:75: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   rate, data = wavfile.read(sound_path)
# 813078_reduced.wav
# 1  from 813078_reduced.wav
# 827691_reduced.wav
# 21  from 827691_reduced.wav
# 831436_reduced.wav
# 1  from 831436_reduced.wav
# 838988_reduced.wav
# 1  from 838988_reduced.wav
# 840246_reduced.wav
# 3  from 840246_reduced.wav
# 844667_reduced.wav
# 16  from 844667_reduced.wav
# 844759_reduced.wav
# 1  from 844759_reduced.wav
# 844760_reduced.wav
# 1  from 844760_reduced.wav
# 863472_reduced.wav
# 1  from 863472_reduced.wav
# 870822_reduced.wav
# 6  from 870822_reduced.wav
# 871057_reduced.wav
# 1  from 871057_reduced.wav
# 871469_reduced.wav
# 1  from 871469_reduced.wav
# 871637_reduced.wav
# 1  from 871637_reduced.wav
# 871707_reduced.wav
# 1  from 871707_reduced.wav
# 871708_reduced.wav
# 1  from 871708_reduced.wav
# 872431_reduced.wav
# 2  from 872431_reduced.wav
# 876460_reduced.wav
# 4  from 876460_reduced.wav
# 877850_reduced.wav
# 1  from 877850_reduced.wav
# 878872_reduced.wav
# 1  from 878872_reduced.wav
# 881155_reduced.wav
# 13  from 881155_reduced.wav
# 883873_reduced.wav
# 1  from 883873_reduced.wav
# 884361_reduced.wav
# 3  from 884361_reduced.wav
# 893489_reduced.wav
# 1  from 893489_reduced.wav
# 894038_reduced.wav
# 1  from 894038_reduced.wav
# 894472_reduced.wav
# 1  from 894472_reduced.wav
# 895049_reduced.wav
# 1  from 895049_reduced.wav
# 895050_reduced.wav
# 1  from 895050_reduced.wav
# 897220_reduced.wav
# 6  from 897220_reduced.wav
# 900233_reduced.wav
# 1  from 900233_reduced.wav
# 900234_reduced.wav
# 1  from 900234_reduced.wav
# 902068_reduced.wav
# 7  from 902068_reduced.wav
# 906162_reduced.wav
# 280  from 906162_reduced.wav
# recycling old stuff
# writing .wav files
# 815762.mp3
# 824118.mp3
# 824859.mp3
# 838179.mp3
# 838180.mp3
# 840681.mp3
# 842379.mp3
# 843135.mp3
# 843227.mp3
# 843228.mp3
# 855697.mp3
# 855820.mp3
# 855821.mp3
# 855822.mp3
# 860776.mp3
# 860777.mp3
# 860778.mp3
# 861052.mp3
# 861053.mp3
# 861572.mp3
# 862566.mp3
# 862567.mp3
# 862568.mp3
# 862725.mp3
# 862726.mp3
# 863210.mp3
# 864148.mp3
# 864373.mp3
# 864374.mp3
# 864375.mp3
# 864376.mp3
# 864563.mp3
# 864564.mp3
# 875536.mp3
# 878170.mp3
# 878890.mp3
# 878892.mp3
# 879408.mp3
# 879427.mp3
# 879428.mp3
# 879429.mp3
# 880826.mp3
# 896272.mp3
# failed for:  ['838179.mp3', '843227.mp3', '843228.mp3', '855820.mp3', '860778.mp3']
# deleting old mp3 files
# 815762_reduced.wav
# 2  from 815762_reduced.wav
# 824118_reduced.wav
# 1  from 824118_reduced.wav
# 824859_reduced.wav
# 1  from 824859_reduced.wav
# 838179_reduced.wav
# 12  from 838179_reduced.wav
# 838180_reduced.wav
# 1  from 838180_reduced.wav
# 840681_reduced.wav
# 1  from 840681_reduced.wav
# 842379_reduced.wav
# 7  from 842379_reduced.wav
# 843135_reduced.wav
# 1  from 843135_reduced.wav
# 843227_reduced.wav
# 1  from 843227_reduced.wav
# 843228_reduced.wav
# 1  from 843228_reduced.wav
# 855697_reduced.wav
# 1  from 855697_reduced.wav
# 855820_reduced.wav
# 2  from 855820_reduced.wav
# 855821_reduced.wav
# 1  from 855821_reduced.wav
# 855822_reduced.wav
# 1  from 855822_reduced.wav
# 860776_reduced.wav
# 1  from 860776_reduced.wav
# 860777_reduced.wav
# 1  from 860777_reduced.wav
# 860778_reduced.wav
# 2  from 860778_reduced.wav
# 861052_reduced.wav
# 1  from 861052_reduced.wav
# 861053_reduced.wav
# 1  from 861053_reduced.wav
# 861572_reduced.wav
# 1  from 861572_reduced.wav
# 862566_reduced.wav
# 1  from 862566_reduced.wav
# 862567_reduced.wav
# 1  from 862567_reduced.wav
# 862568_reduced.wav
# 1  from 862568_reduced.wav
# 862725_reduced.wav
# 1  from 862725_reduced.wav
# 862726_reduced.wav
# 1  from 862726_reduced.wav
# 863210_reduced.wav
# 1  from 863210_reduced.wav
# 864148_reduced.wav
# 1  from 864148_reduced.wav
# 864373_reduced.wav
# 1  from 864373_reduced.wav
# 864374_reduced.wav
# 1  from 864374_reduced.wav
# 864375_reduced.wav
# 1  from 864375_reduced.wav
# 864376_reduced.wav
# 1  from 864376_reduced.wav
# 864563_reduced.wav
# 1  from 864563_reduced.wav
# 864564_reduced.wav
# 1  from 864564_reduced.wav
# 875536_reduced.wav
# 4  from 875536_reduced.wav
# 878170_reduced.wav
# 2  from 878170_reduced.wav
# 878890_reduced.wav
# 1  from 878890_reduced.wav
# 878892_reduced.wav
# 8  from 878892_reduced.wav
# 879408_reduced.wav
# 2  from 879408_reduced.wav
# 879427_reduced.wav
# 1  from 879427_reduced.wav
# 879428_reduced.wav
# 1  from 879428_reduced.wav
# 879429_reduced.wav
# 7  from 879429_reduced.wav
# 880826_reduced.wav
# 1  from 880826_reduced.wav
# 896272_reduced.wav
# 33  from 896272_reduced.wav
# recycling old stuff
# writing .wav files
# 806433.mp3
# 806892.mp3
# 807108.mp3
# 807722.mp3
# 807863.mp3
# 807985.mp3
# 807986.mp3
# 807987.mp3
# 808285.mp3
# 808717.mp3
# 809220.mp3
# 809399.mp3
# 810058.mp3
# 810060.mp3
# 810061.mp3
# 810072.mp3
# 811279.mp3
# 811393.mp3
# 811564.mp3
# 811991.mp3
# 813555.mp3
# 813556.mp3
# 813557.mp3
# 814141.mp3
# 814261.mp3
# 814262.mp3
# 814828.mp3
# 815294.mp3
# 815744.mp3
# 815904.mp3
# 815905.mp3
# 815906.mp3
# 818834.mp3
# 819239.mp3
# 819338.mp3
# 819696.mp3
# 820042.mp3
# 820443.mp3
# 820768.mp3
# 820769.mp3
# 821900.mp3
# 822476.mp3
# 823016.mp3
# 823505.mp3
# 826350.mp3
# 828881.mp3
# 830563.mp3
# 830605.mp3
# 831443.mp3
# 832101.mp3
# 832368.mp3
# 832418.mp3
# 832419.mp3
# 832627.mp3
# 832628.mp3
# 832643.mp3
# 833265.mp3
# 833617.mp3
# 833620.mp3
# 833621.mp3
# 833622.mp3
# 833623.mp3
# 834802.mp3
# 838178.mp3
# 839062.mp3
# 839063.mp3
# 839129.mp3
# 839862.mp3
# 840402.mp3
# 840455.mp3
# 840646.mp3
# 840699.mp3
# 841519.mp3
# 842023.mp3
# 842228.mp3
# 842243.mp3
# 842245.mp3
# 843474.mp3
# 843484.mp3
# 843489.mp3
# 843561.mp3
# 844847.mp3
# 845019.mp3
# 845912.mp3
# 846066.mp3
# 853713.mp3
# 854541.mp3
# 855116.mp3
# 855469.mp3
# 855713.mp3
# 857250.mp3
# 857252.mp3
# 857253.mp3
# 857264.mp3
# 857603.mp3
# 857604.mp3
# 857899.mp3
# 858289.mp3
# 858706.mp3
# 858707.mp3
# 859068.mp3
# 859080.mp3
# 859131.mp3
# 860320.mp3
# 860551.mp3
# 861128.mp3
# 861494.mp3
# 861823.mp3
# 861940.mp3
# 862138.mp3
# 862145.mp3
# 862285.mp3
# 862401.mp3
# 862402.mp3
# 862927.mp3
# 862928.mp3
# 863148.mp3
# 863709.mp3
# 864120.mp3
# 864297.mp3
# 864321.mp3
# 864603.mp3
# 865022.mp3
# 865909.mp3
# 865913.mp3
# 865917.mp3
# 865923.mp3
# 870671.mp3
# 870729.mp3
# 870733.mp3
# 870927.mp3
# 871066.mp3
# 871177.mp3
# 871303.mp3
# 871382.mp3
# 871383.mp3
# 871607.mp3
# 872019.mp3
# 872022.mp3
# 872283.mp3
# 872696.mp3
# 872823.mp3
# 872933.mp3
# 874098.mp3
# 875341.mp3
# 875342.mp3
# 875343.mp3
# 875551.mp3
# 876227.mp3
# 876228.mp3
# 877128.mp3
# 877504.mp3
# 877554.mp3
# 877558.mp3
# 877559.mp3
# 877604.mp3
# 877723.mp3
# 877996.mp3
# 878089.mp3
# 878102.mp3
# 878806.mp3
# 878813.mp3
# 878815.mp3
# 878817.mp3
# 878869.mp3
# 878870.mp3
# 879197.mp3
# 879198.mp3
# 879374.mp3
# 879375.mp3
# 879378.mp3
# 879379.mp3
# 879399.mp3
# 879577.mp3
# 879770.mp3
# 879815.mp3
# 879816.mp3
# 879929.mp3
# 879940.mp3
# 880732.mp3
# 880931.mp3
# 881387.mp3
# 881388.mp3
# 881427.mp3
# 881706.mp3
# 881921.mp3
# 881937.mp3
# 883120.mp3
# 883339.mp3
# 883378.mp3
# 883597.mp3
# 884600.mp3
# 884604.mp3
# 884608.mp3
# 884624.mp3
# 884817.mp3
# 884841.mp3
# 889958.mp3
# 890305.mp3
# 890306.mp3
# 890648.mp3
# 891342.mp3
# 892848.mp3
# 893380.mp3
# 893383.mp3
# 894078.mp3
# 894572.mp3
# 894866.mp3
# 895153.mp3
# 895207.mp3
# 896544.mp3
# 897043.mp3
# 897490.mp3
# 897551.mp3
# 897574.mp3
# 897677.mp3
# 897748.mp3
# 897749.mp3
# 898512.mp3
# 898527.mp3
# 898552.mp3
# 898829.mp3
# 899081.mp3
# 899354.mp3
# 899356.mp3
# 899357.mp3
# 899545.mp3
# 899637.mp3
# 899976.mp3
# 901667.mp3
# 901954.mp3
# 901956.mp3
# 902005.mp3
# 902006.mp3
# 902008.mp3
# 902010.mp3
# 902012.mp3
# 902013.mp3
# 902014.mp3
# 902016.mp3
# 902017.mp3
# 902018.mp3
# 902019.mp3
# 902021.mp3
# 902611.mp3
# 902756.mp3
# 902949.mp3
# 902959.mp3
# 902961.mp3
# 904894.mp3
# 904895.mp3
# 904896.mp3
# 904897.mp3
# 904898.mp3
# 904899.mp3
# 904900.mp3
# 904901.mp3
# 904902.mp3
# 904903.mp3
# 904904.mp3
# 904906.mp3
# 904907.mp3
# 904909.mp3
# 905246.mp3
# 905525.mp3
# 905527.mp3
# 906512.mp3
# failed for:  ['814262.mp3', '832419.mp3', '862927.mp3', '875551.mp3', '877604.mp3', '890305.mp3', '890648.mp3', '897043.mp3', '902949.mp3']
# deleting old mp3 files
# C:\dumi\bird_reco\.venv\lib\site-packages\noisereduce\spectralgate\base.py:226: RuntimeWarning: invalid value encountered in cast
#   return filtered_chunk.astype(self._dtype)
# 806433_reduced.wav
# 14  from 806433_reduced.wav
# 806892_reduced.wav
# 16  from 806892_reduced.wav
# 807108_reduced.wav
# 40  from 807108_reduced.wav
# 807722_reduced.wav
# 4  from 807722_reduced.wav
# 807863_reduced.wav
# 29  from 807863_reduced.wav
# 807985_reduced.wav
# 32  from 807985_reduced.wav
# 807986_reduced.wav
# 34  from 807986_reduced.wav
# 807987_reduced.wav
# 5  from 807987_reduced.wav
# 808285_reduced.wav
# 5  from 808285_reduced.wav
# 808717_reduced.wav
# 15  from 808717_reduced.wav
# 809220_reduced.wav
# 4  from 809220_reduced.wav
# 809399_reduced.wav
# 1  from 809399_reduced.wav
# 810058_reduced.wav
# 67  from 810058_reduced.wav
# 810060_reduced.wav
# 16  from 810060_reduced.wav
# 810061_reduced.wav
# 7  from 810061_reduced.wav
# 810072_reduced.wav
# 5  from 810072_reduced.wav
# 811279_reduced.wav
# 1  from 811279_reduced.wav
# 811393_reduced.wav
# 1  from 811393_reduced.wav
# 811564_reduced.wav
# 14  from 811564_reduced.wav
# recycling old stuff
# writing .wav files
# 805909.mp3
# 805912.mp3
# 806871.mp3
# 806872.mp3
# 806876.mp3
# 806878.mp3
# 806978.mp3
# 806981.mp3
# 807239.mp3
# 808415.mp3
# 808416.mp3
# 808710.mp3
# 808711.mp3
# 809029.mp3
# 809176.mp3
# 812819.mp3
# 812994.mp3
# 812995.mp3
# 813320.mp3
# 814801.mp3
# 814802.mp3
# 815611.mp3
# 815890.mp3
# 816178.mp3
# 816468.mp3
# 817177.mp3
# 818715.mp3
# 820531.mp3
# 820860.mp3
# 820867.mp3
# 820869.mp3
# 820870.mp3
# 820871.mp3
# 820873.mp3
# 822503.mp3
# 828372.mp3
# 828381.mp3
# 828384.mp3
# 828386.mp3
# 828398.mp3
# 828399.mp3
# 828413.mp3
# 829219.mp3
# 830505.mp3
# 830821.mp3
# 830822.mp3
# 830823.mp3
# 830960.mp3
# 830961.mp3
# 830962.mp3
# 830963.mp3
# 830965.mp3
# 830966.mp3
# 830967.mp3
# 830968.mp3
# 830969.mp3
# 830970.mp3
# 830971.mp3
# 830972.mp3
# 830973.mp3
# 830974.mp3
# 830976.mp3
# 831824.mp3
# 831825.mp3
# 831830.mp3
# 832064.mp3
# 833043.mp3
# 833045.mp3
# 833055.mp3
# 833056.mp3
# 833058.mp3
# 833059.mp3
# 833373.mp3
# 833377.mp3
# 834783.mp3
# 834785.mp3
# 834786.mp3
# 834787.mp3
# 834788.mp3
# 834805.mp3
# 834806.mp3
# 834931.mp3
# 834932.mp3
# 834933.mp3
# 836124.mp3
# 836125.mp3
# 836129.mp3
# 836151.mp3
# 836153.mp3
# 836154.mp3
# 836155.mp3
# 836156.mp3
# 845494.mp3
# 869154.mp3
# 870023.mp3
# 871751.mp3
# 872032.mp3
# 872040.mp3
# 872041.mp3
# 872042.mp3
# 872044.mp3
# 872045.mp3
# 875268.mp3
# 875272.mp3
# 875273.mp3
# 875335.mp3
# 878596.mp3
# 878597.mp3
# 879034.mp3
# 879035.mp3
# 879380.mp3
# 879384.mp3
# 879385.mp3
# 879386.mp3
# 879763.mp3
# 880902.mp3
# 881274.mp3
# 884864.mp3
# 891807.mp3
# 892350.mp3
# 892354.mp3
# 892358.mp3
# 892368.mp3
# 892369.mp3
# 892375.mp3
# 893708.mp3
# 894685.mp3
# 894687.mp3
# 894688.mp3
# 895118.mp3
# 895122.mp3
# 895712.mp3
# 899112.mp3
# 899114.mp3
# 899641.mp3
# 900498.mp3
# 900570.mp3
# 901327.mp3
# 901668.mp3
# 901796.mp3
# 901969.mp3
# 903150.mp3
# 903364.mp3
# 903365.mp3
# 903366.mp3
# 903367.mp3
# 903368.mp3
# 903369.mp3
# 903371.mp3
# 903439.mp3
# 903540.mp3
# 903542.mp3
# 903543.mp3
# 905587.mp3
# 905588.mp3
# 905590.mp3
# 905591.mp3
# 905593.mp3
# 905594.mp3
# 905595.mp3
# 905596.mp3
# 905597.mp3
# 905599.mp3
# 905600.mp3
# 906015.mp3
# failed for:  ['805912.mp3', '806878.mp3', '808416.mp3', '808711.mp3', '828372.mp3', '830821.mp3', '830823.mp3', '830960.mp3', '833045.mp3', '836155.mp3', '869154.mp3', '870023.mp3', '871751.mp3', '872032.mp3', '878597.mp3', '879034.mp3', '881274.mp3', '892368.mp3', '892369.mp3', '901668.mp3', '901969.mp3', '903439.mp3']
# deleting old mp3 files
# 805909_reduced.wav
# 1  from 805909_reduced.wav
# 805912_reduced.wav
# 1  from 805912_reduced.wav
# 806871_reduced.wav
# 2  from 806871_reduced.wav
# 806872_reduced.wav
# 1  from 806872_reduced.wav
# 806876_reduced.wav
# 1  from 806876_reduced.wav
# 806878_reduced.wav
# 15  from 806878_reduced.wav
# 806978_reduced.wav
# 3  from 806978_reduced.wav
# 806981_reduced.wav
# 1  from 806981_reduced.wav
# 807239_reduced.wav
# 1  from 807239_reduced.wav
# 808415_reduced.wav
# 1  from 808415_reduced.wav
# 808416_reduced.wav
# 1  from 808416_reduced.wav
# 808710_reduced.wav
# 1  from 808710_reduced.wav
# 808711_reduced.wav
# 5  from 808711_reduced.wav
# 809029_reduced.wav
# 1  from 809029_reduced.wav
# 809176_reduced.wav
# 1  from 809176_reduced.wav
# 812819_reduced.wav
# 1  from 812819_reduced.wav
# 812994_reduced.wav
# 1  from 812994_reduced.wav
# 812995_reduced.wav
# 1  from 812995_reduced.wav
# 813320_reduced.wav
# 13  from 813320_reduced.wav
# 814801_reduced.wav
# 1  from 814801_reduced.wav
# 814802_reduced.wav
# 1  from 814802_reduced.wav
# 815611_reduced.wav
# 1  from 815611_reduced.wav
# 815890_reduced.wav
# 19  from 815890_reduced.wav
# 816178_reduced.wav
# 1  from 816178_reduced.wav
# 816468_reduced.wav
# 1  from 816468_reduced.wav
# 817177_reduced.wav
# 1  from 817177_reduced.wav
# 818715_reduced.wav
# 3  from 818715_reduced.wav
# 820531_reduced.wav
# 1  from 820531_reduced.wav
# 820860_reduced.wav
# 1  from 820860_reduced.wav
# 820867_reduced.wav
# 2  from 820867_reduced.wav
# 820869_reduced.wav
# 3  from 820869_reduced.wav
# 820870_reduced.wav
# 2  from 820870_reduced.wav
# 820871_reduced.wav
# 4  from 820871_reduced.wav
# 820873_reduced.wav
# 1  from 820873_reduced.wav
# 822503_reduced.wav
# 2  from 822503_reduced.wav
# 828372_reduced.wav
# 1  from 828372_reduced.wav
# 828381_reduced.wav
# 1  from 828381_reduced.wav
# 828384_reduced.wav
# 1  from 828384_reduced.wav
# 828386_reduced.wav
# 1  from 828386_reduced.wav
# 828398_reduced.wav
# 1  from 828398_reduced.wav
# 828399_reduced.wav
# 1  from 828399_reduced.wav
# 828413_reduced.wav
# 1  from 828413_reduced.wav
# 829219_reduced.wav
# 1  from 829219_reduced.wav
# 830505_reduced.wav
# 1  from 830505_reduced.wav
# 830821_reduced.wav
# 4  from 830821_reduced.wav
# 830822_reduced.wav
# 1  from 830822_reduced.wav
# 830823_reduced.wav
# 2  from 830823_reduced.wav
# 830960_reduced.wav
# 1  from 830960_reduced.wav
# 830961_reduced.wav
# 1  from 830961_reduced.wav
# 830962_reduced.wav
# 1  from 830962_reduced.wav
# 830963_reduced.wav
# 1  from 830963_reduced.wav
# 830965_reduced.wav
# 1  from 830965_reduced.wav
# 830966_reduced.wav
# 1  from 830966_reduced.wav
# 830967_reduced.wav
# 1  from 830967_reduced.wav
# 830968_reduced.wav
# 1  from 830968_reduced.wav
# 830969_reduced.wav
# 1  from 830969_reduced.wav
# 830970_reduced.wav
# 1  from 830970_reduced.wav
# 830971_reduced.wav
# 1  from 830971_reduced.wav
# 830972_reduced.wav
# 1  from 830972_reduced.wav
# 830973_reduced.wav
# 1  from 830973_reduced.wav
# 830974_reduced.wav
# 1  from 830974_reduced.wav
# 830976_reduced.wav
# 1  from 830976_reduced.wav
# 831824_reduced.wav
# 1  from 831824_reduced.wav
# 831825_reduced.wav
# 1  from 831825_reduced.wav
# 831830_reduced.wav
# 1  from 831830_reduced.wav
# 832064_reduced.wav
# 2  from 832064_reduced.wav
# 833043_reduced.wav
# 1  from 833043_reduced.wav
# 833045_reduced.wav
# 1  from 833045_reduced.wav
# 833055_reduced.wav
# 1  from 833055_reduced.wav
# 833056_reduced.wav
# 1  from 833056_reduced.wav
# 833058_reduced.wav
# 1  from 833058_reduced.wav
# 833059_reduced.wav
# 1  from 833059_reduced.wav
# 833373_reduced.wav
# 1  from 833373_reduced.wav
# 833377_reduced.wav
# 1  from 833377_reduced.wav
# 834783_reduced.wav
# 12  from 834783_reduced.wav
# 834785_reduced.wav
# 36  from 834785_reduced.wav
# 834786_reduced.wav
# 4  from 834786_reduced.wav
# 834787_reduced.wav
# 5  from 834787_reduced.wav
# 834788_reduced.wav
# 9  from 834788_reduced.wav
# 834805_reduced.wav
# 1  from 834805_reduced.wav
# 834806_reduced.wav
# 1  from 834806_reduced.wav
# 834931_reduced.wav
# 7  from 834931_reduced.wav
# 834932_reduced.wav
# 3  from 834932_reduced.wav
# 834933_reduced.wav
# 6  from 834933_reduced.wav
# 836124_reduced.wav
# 1  from 836124_reduced.wav
# 836125_reduced.wav
# 1  from 836125_reduced.wav
# 836129_reduced.wav
# 1  from 836129_reduced.wav
# 836151_reduced.wav
# 1  from 836151_reduced.wav
# 836153_reduced.wav
# 1  from 836153_reduced.wav
# 836154_reduced.wav
# 1  from 836154_reduced.wav
# 836155_reduced.wav
# 2  from 836155_reduced.wav
# 836156_reduced.wav
# 1  from 836156_reduced.wav
# 845494_reduced.wav
# 1  from 845494_reduced.wav
# 869154_reduced.wav
# 1  from 869154_reduced.wav
# 870023_reduced.wav
# 1  from 870023_reduced.wav
# 871751_reduced.wav
# 3  from 871751_reduced.wav
# 872032_reduced.wav
# 3  from 872032_reduced.wav
# 872040_reduced.wav
# 1  from 872040_reduced.wav
# 872041_reduced.wav
# 1  from 872041_reduced.wav
# 872042_reduced.wav
# 1  from 872042_reduced.wav
# 872044_reduced.wav
# 1  from 872044_reduced.wav
# 872045_reduced.wav
# 1  from 872045_reduced.wav
# 875268_reduced.wav
# 1  from 875268_reduced.wav
# 875272_reduced.wav
# 1  from 875272_reduced.wav
# 875273_reduced.wav
# 1  from 875273_reduced.wav
# 875335_reduced.wav
# 1  from 875335_reduced.wav
# 878596_reduced.wav
# 1  from 878596_reduced.wav
# 878597_reduced.wav
# 7  from 878597_reduced.wav
# 879034_reduced.wav
# 4  from 879034_reduced.wav
# 879035_reduced.wav
# 1  from 879035_reduced.wav
# 879380_reduced.wav
# 7  from 879380_reduced.wav
# 879384_reduced.wav
# 16  from 879384_reduced.wav
# 879385_reduced.wav
# 14  from 879385_reduced.wav
# recycling old stuff
# writing .wav files
# 807507.mp3
# 818663.mp3
# 819669.mp3
# 821061.mp3
# 822751.mp3
# 824433.mp3
# 829348.mp3
# 830296.mp3
# 832692.mp3
# 837510.mp3
# 839137.mp3
# 839138.mp3
# 840620.mp3
# 841787.mp3
# 842809.mp3
# 843320.mp3
# 844555.mp3
# 844588.mp3
# 845497.mp3
# 857948.mp3
# 857972.mp3
# 862045.mp3
# 864264.mp3
# 872057.mp3
# 872348.mp3
# 876170.mp3
# 876171.mp3
# 877553.mp3
# 878611.mp3
# 878740.mp3
# 878741.mp3
# 878950.mp3
# 878951.mp3
# 878952.mp3
# 880672.mp3
# 881356.mp3
# 881847.mp3
# 881881.mp3
# 881882.mp3
# 882189.mp3
# 882416.mp3
# 882536.mp3
# 883739.mp3
# 890793.mp3
# 891897.mp3
# 892338.mp3
# 893775.mp3
# 894041.mp3
# 894329.mp3
# 894331.mp3
# 894400.mp3
# 894750.mp3
# 895619.mp3
# 896331.mp3
# 897301.mp3
# 897438.mp3
# 897660.mp3
# 899108.mp3
# 899328.mp3
# 899986.mp3
# 903531.mp3
# 906646.mp3
# failed for:  ['818663.mp3', '821061.mp3', '830296.mp3', '837510.mp3', '844588.mp3', '845497.mp3', '857948.mp3', '894329.mp3', '899108.mp3']
# deleting old mp3 files
# 807507_reduced.wav
# 1  from 807507_reduced.wav
# 818663_reduced.wav
# 2  from 818663_reduced.wav
# 819669_reduced.wav
# 4  from 819669_reduced.wav
# 821061_reduced.wav
# 6  from 821061_reduced.wav
# 822751_reduced.wav
# 2  from 822751_reduced.wav
# 824433_reduced.wav
# 25  from 824433_reduced.wav
# 829348_reduced.wav
# 1  from 829348_reduced.wav
# 830296_reduced.wav
# 7  from 830296_reduced.wav
# 832692_reduced.wav
# 1  from 832692_reduced.wav
# 837510_reduced.wav
# 5  from 837510_reduced.wav
# 839137_reduced.wav
# 14  from 839137_reduced.wav
# 839138_reduced.wav
# 6  from 839138_reduced.wav
# 840620_reduced.wav
# 4  from 840620_reduced.wav
# 841787_reduced.wav
# 10  from 841787_reduced.wav
# 842809_reduced.wav
# 7  from 842809_reduced.wav
# 843320_reduced.wav
# 1  from 843320_reduced.wav
# 844555_reduced.wav
# 1  from 844555_reduced.wav
# 844588_reduced.wav
# 1  from 844588_reduced.wav
# 845497_reduced.wav
# 6  from 845497_reduced.wav
# 857948_reduced.wav
# 2  from 857948_reduced.wav
# 857972_reduced.wav
# 1  from 857972_reduced.wav
# 862045_reduced.wav
# 1  from 862045_reduced.wav
# 864264_reduced.wav
# 1  from 864264_reduced.wav
# 872057_reduced.wav
# 5  from 872057_reduced.wav
# 872348_reduced.wav
# 1  from 872348_reduced.wav
# 876170_reduced.wav
# 36  from 876170_reduced.wav
# 876171_reduced.wav
# 14  from 876171_reduced.wav
# 877553_reduced.wav
# 1  from 877553_reduced.wav
# 878611_reduced.wav
# 4  from 878611_reduced.wav
# 878740_reduced.wav
# 7  from 878740_reduced.wav
# 878741_reduced.wav
# 3  from 878741_reduced.wav
# 878950_reduced.wav
# 1  from 878950_reduced.wav
# 878951_reduced.wav
# 1  from 878951_reduced.wav
# 878952_reduced.wav
# 1  from 878952_reduced.wav
# 880672_reduced.wav
# 5  from 880672_reduced.wav
# 881356_reduced.wav
# 1  from 881356_reduced.wav
# 881847_reduced.wav
# 1  from 881847_reduced.wav
# 881881_reduced.wav
# 3  from 881881_reduced.wav
# 881882_reduced.wav
# 8  from 881882_reduced.wav
# 882189_reduced.wav
# 1  from 882189_reduced.wav
# 882416_reduced.wav
# 1  from 882416_reduced.wav
# 882536_reduced.wav
# 1  from 882536_reduced.wav
# 883739_reduced.wav
# 1  from 883739_reduced.wav
# 890793_reduced.wav
# 5  from 890793_reduced.wav
# 891897_reduced.wav
# 15  from 891897_reduced.wav
# 892338_reduced.wav
# 2  from 892338_reduced.wav
# 893775_reduced.wav
# 1  from 893775_reduced.wav
# 894041_reduced.wav
# 8  from 894041_reduced.wav
# 894329_reduced.wav
# 11  from 894329_reduced.wav
# 894331_reduced.wav
# 1  from 894331_reduced.wav
# 894400_reduced.wav
# 1  from 894400_reduced.wav
# 894750_reduced.wav
# 7  from 894750_reduced.wav
# 895619_reduced.wav
# 2  from 895619_reduced.wav
# 896331_reduced.wav
# 1  from 896331_reduced.wav
# 897301_reduced.wav
# 19  from 897301_reduced.wav
# 897438_reduced.wav
# 1  from 897438_reduced.wav
# 897660_reduced.wav
# 1  from 897660_reduced.wav
# 899108_reduced.wav
# 1  from 899108_reduced.wav
# 899328_reduced.wav
# 1  from 899328_reduced.wav
# 899986_reduced.wav
# 17  from 899986_reduced.wav
# 903531_reduced.wav
# 1  from 903531_reduced.wav
# 906646_reduced.wav
# 1  from 906646_reduced.wav
# recycling old stuff
# writing .wav files
# 806398.mp3
# 806401.mp3
# 806498.mp3
# 806564.mp3
# 806671.mp3
# 807085.mp3
# 807677.mp3
# 807914.mp3
# 807916.mp3
# 808065.mp3
# 808186.mp3
# 808461.mp3
# 808462.mp3
# 808463.mp3
# 808464.mp3
# 808507.mp3
# 808921.mp3
# 809275.mp3
# 809349.mp3
# 809401.mp3
# 809403.mp3
# 809761.mp3
# 809764.mp3
# 809771.mp3
# 810364.mp3
# 810398.mp3
# 811637.mp3
# 811646.mp3
# 811679.mp3
# 811766.mp3
# 811783.mp3
# 811870.mp3
# 812331.mp3
# 812334.mp3
# 812335.mp3
# 812336.mp3
# 812337.mp3
# 812338.mp3
# 812339.mp3
# 812509.mp3
# 812510.mp3
# 812519.mp3
# 812520.mp3
# 812585.mp3
# 814431.mp3
# 814799.mp3
# 814835.mp3
# 815451.mp3
# 815754.mp3
# 816459.mp3
# 816670.mp3
# 817764.mp3
# 817957.mp3
# 818185.mp3
# 818441.mp3
# 818823.mp3
# 818824.mp3
# 819026.mp3
# 819398.mp3
# 819405.mp3
# 820328.mp3
# 821165.mp3
# 821532.mp3
# 821534.mp3
# 821535.mp3
# 822250.mp3
# 822251.mp3
# 822258.mp3
# 822425.mp3
# 822600.mp3
# 826604.mp3
# 828567.mp3
# 828770.mp3
# 828871.mp3
# 830584.mp3
# 831200.mp3
# 831491.mp3
# 832025.mp3
# 832028.mp3
# 832131.mp3
# 834601.mp3
# 838620.mp3
# 839000.mp3
# 839737.mp3
# 839738.mp3
# 841354.mp3
# 842053.mp3
# 842054.mp3
# 842801.mp3
# 842904.mp3
# 843665.mp3
# 845125.mp3
# 845983.mp3
# 855470.mp3
# 855486.mp3
# 858534.mp3
# 859343.mp3
# 859344.mp3
# 859477.mp3
# 859478.mp3
# 859479.mp3
# 859480.mp3
# 859481.mp3
# 859482.mp3
# 859483.mp3
# 860522.mp3
# 861198.mp3
# 861759.mp3
# 861908.mp3
# 861909.mp3
# 861910.mp3
# 861911.mp3
# 861915.mp3
# 862627.mp3
# 863537.mp3
# 863538.mp3
# 863539.mp3
# 863540.mp3
# 863541.mp3
# 863542.mp3
# 863543.mp3
# 863544.mp3
# 863545.mp3
# 863546.mp3
# 863547.mp3
# 864031.mp3
# 865993.mp3
# 870708.mp3
# 870714.mp3
# 870832.mp3
# 870982.mp3
# 871463.mp3
# 871584.mp3
# 871703.mp3
# 871789.mp3
# 871877.mp3
# 872076.mp3
# 872139.mp3
# 872584.mp3
# 877581.mp3
# 877582.mp3
# 877997.mp3
# 878369.mp3
# 879802.mp3
# 881150.mp3
# 881151.mp3
# 881158.mp3
# 881167.mp3
# 881173.mp3
# 881174.mp3
# 881175.mp3
# 881176.mp3
# 881177.mp3
# 881423.mp3
# 881781.mp3
# 881784.mp3
# 883116.mp3
# 883317.mp3
# 883353.mp3
# 883616.mp3
# 884657.mp3
# 884701.mp3
# 884915.mp3
# 889838.mp3
# 890127.mp3
# 890640.mp3
# 891339.mp3
# 891499.mp3
# 892291.mp3
# 892472.mp3
# 892600.mp3
# 892713.mp3
# 892715.mp3
# 892719.mp3
# 892720.mp3
# 893619.mp3
# 893739.mp3
# 893747.mp3
# 894148.mp3
# 894149.mp3
# 894428.mp3
# 894448.mp3
# 894558.mp3
# 894559.mp3
# 894571.mp3
# 894696.mp3
# 894698.mp3
# 895449.mp3
# 896770.mp3
# 896964.mp3
# 897016.mp3
# 897112.mp3
# 897229.mp3
# 897397.mp3
# 897459.mp3
# 897966.mp3
# 898097.mp3
# 898098.mp3
# 898417.mp3
# 899033.mp3
# 899490.mp3
# 899732.mp3
# 899745.mp3
# 899747.mp3
# 899820.mp3
# 899822.mp3
# 899823.mp3
# 899892.mp3
# 899979.mp3
# 900226.mp3
# 900826.mp3
# 900893.mp3
# 900966.mp3
# 901144.mp3
# 901388.mp3
# 901391.mp3
# 901482.mp3
# 901601.mp3
# 901901.mp3
# 901948.mp3
# 901950.mp3
# 901951.mp3
# 901952.mp3
# 901953.mp3
# 901957.mp3
# 902793.mp3
# 902794.mp3
# 902796.mp3
# 903929.mp3
# 904600.mp3
# 904601.mp3
# 904603.mp3
# 904682.mp3
# 904887.mp3
# 904888.mp3
# 904889.mp3
# 904890.mp3
# 904891.mp3
# 904975.mp3
# 905327.mp3
# 905351.mp3
# 905466.mp3
# 905478.mp3
# 905579.mp3
# 905602.mp3
# 905603.mp3
# 905605.mp3
# 906152.mp3
# 906254.mp3
# 906281.mp3
# 906506.mp3
# 906507.mp3
# 906521.mp3
# 906522.mp3
# 906523.mp3
# 908632.mp3
# 908633.mp3
# 908635.mp3
# 908812.mp3
# failed for:  ['807914.mp3', '807916.mp3', '808186.mp3', '842904.mp3', '870982.mp3', '890127.mp3', '901901.mp3']
# deleting old mp3 files
# C:\Users\ciaun\AppData\Local\Temp\ipykernel_16592\1178939392.py:75: WavFileWarning: Reached EOF prematurely; finished at 1723002 bytes, expected 1723010 bytes from header.
#   rate, data = wavfile.read(sound_path)
# C:\dumi\bird_reco\.venv\lib\site-packages\noisereduce\spectralgate\base.py:164: RuntimeWarning: invalid value encountered in cast
#   filtered_chunk[:, pos: pos + end0 - start0] = filtered_chunk0[:, start0:end0]
# 806398_reduced.wav
# 1  from 806398_reduced.wav
# 806401_reduced.wav
# 1  from 806401_reduced.wav
# 806498_reduced.wav
# 5  from 806498_reduced.wav
# 806564_reduced.wav
# 15  from 806564_reduced.wav
# 806671_reduced.wav
# 21  from 806671_reduced.wav
# 807085_reduced.wav
# 10  from 807085_reduced.wav
# 807677_reduced.wav
# 10  from 807677_reduced.wav
# 807914_reduced.wav
# 7  from 807914_reduced.wav
# 807916_reduced.wav
# 6  from 807916_reduced.wav
# 808065_reduced.wav
# 1  from 808065_reduced.wav
# 808186_reduced.wav
# 30  from 808186_reduced.wav
# 808461_reduced.wav
# 1  from 808461_reduced.wav
# 808462_reduced.wav
# 1  from 808462_reduced.wav
# 808463_reduced.wav
# 1  from 808463_reduced.wav
# 808464_reduced.wav
# 1  from 808464_reduced.wav
# 808507_reduced.wav
# 6  from 808507_reduced.wav
# 808921_reduced.wav
# 46  from 808921_reduced.wav
# 809275_reduced.wav
# 8  from 809275_reduced.wav
# 809349_reduced.wav
# 8  from 809349_reduced.wav
# 809401_reduced.wav
# 1  from 809401_reduced.wav
# 809403_reduced.wav
# 1  from 809403_reduced.wav
# 809761_reduced.wav
# 49  from 809761_reduced.wav
# 809764_reduced.wav
# 23  from 809764_reduced.wav
# 809771_reduced.wav
# 5  from 809771_reduced.wav
# 810364_reduced.wav
# 8  from 810364_reduced.wav
# 810398_reduced.wav
# 31  from 810398_reduced.wav
# 811637_reduced.wav
# 1  from 811637_reduced.wav
# 811646_reduced.wav
# 1  from 811646_reduced.wav
# 811679_reduced.wav
# 1  from 811679_reduced.wav
# 811766_reduced.wav
# 7  from 811766_reduced.wav
# recycling old stuff
# writing .wav files
# 808106.mp3
# 809070.mp3
# 809735.mp3
# 810451.mp3
# 810553.mp3
# 811695.mp3
# 811770.mp3
# 814991.mp3
# 815509.mp3
# 819022.mp3
# 825472.mp3
# 825473.mp3
# 826364.mp3
# 826365.mp3
# 829395.mp3
# 829444.mp3
# 829603.mp3
# 829604.mp3
# 829606.mp3
# 829608.mp3
# 829684.mp3
# 854813.mp3
# 861748.mp3
# 863161.mp3
# 871908.mp3
# 876585.mp3
# 876587.mp3
# 878590.mp3
# 878724.mp3
# 879203.mp3
# 879417.mp3
# 880517.mp3
# 881944.mp3
# 881963.mp3
# 881964.mp3
# 881974.mp3
# 882137.mp3
# 882366.mp3
# 884684.mp3
# 884741.mp3
# 891855.mp3
# 892371.mp3
# 893030.mp3
# 893609.mp3
# 894251.mp3
# 894919.mp3
# 895989.mp3
# 897306.mp3
# 897312.mp3
# 898109.mp3
# 900582.mp3
# 900927.mp3
# 901314.mp3
# 902454.mp3
# 902800.mp3
# 906178.mp3
# 906395.mp3
# 906720.mp3
# failed for:  ['808106.mp3', '826365.mp3', '884684.mp3', '898109.mp3']
# deleting old mp3 files
# 808106_reduced.wav
# 5  from 808106_reduced.wav
# 809070_reduced.wav
# 1  from 809070_reduced.wav
# 809735_reduced.wav
# 52  from 809735_reduced.wav
# 810451_reduced.wav
# 1  from 810451_reduced.wav
# 810553_reduced.wav
# 1  from 810553_reduced.wav
# 811695_reduced.wav
# 1  from 811695_reduced.wav
# 811770_reduced.wav
# 23  from 811770_reduced.wav
# 814991_reduced.wav
# 1  from 814991_reduced.wav
# 815509_reduced.wav
# 8  from 815509_reduced.wav
# 819022_reduced.wav
# 52  from 819022_reduced.wav
# 825472_reduced.wav
# 33  from 825472_reduced.wav
# 825473_reduced.wav
# 116  from 825473_reduced.wav
# 826364_reduced.wav
# 1  from 826364_reduced.wav
# 826365_reduced.wav
# 6  from 826365_reduced.wav
# recycling old stuff
# writing .wav files
# 806437.mp3
# 814130.mp3
# 832135.mp3
# 834919.mp3
# 834921.mp3
# 839104.mp3
# 840427.mp3
# 841971.mp3
# 855171.mp3
# 872141.mp3
# 884129.mp3
# failed for:  []
# deleting old mp3 files
# 806437_reduced.wav
# 39  from 806437_reduced.wav
# 814130_reduced.wav
# 2  from 814130_reduced.wav
# 832135_reduced.wav
# 1  from 832135_reduced.wav
# 834919_reduced.wav
# 5  from 834919_reduced.wav
# 834921_reduced.wav
# 1  from 834921_reduced.wav
# 839104_reduced.wav
# 1  from 839104_reduced.wav
# 840427_reduced.wav
# 3  from 840427_reduced.wav
# 841971_reduced.wav
# 6  from 841971_reduced.wav
# 855171_reduced.wav
# 20  from 855171_reduced.wav
# 872141_reduced.wav
# 1  from 872141_reduced.wav
# 884129_reduced.wav
# 26  from 884129_reduced.wav
# recycling old stuff
# writing .wav files
# 806090.mp3
# 807305.mp3
# 807982.mp3
# 808862.mp3
# 809722.mp3
# 812093.mp3
# 812094.mp3
# 812095.mp3
# 813162.mp3
# 813506.mp3
# 815975.mp3
# 819044.mp3
# 823988.mp3
# 824055.mp3
# 826610.mp3
# 828673.mp3
# 828675.mp3
# 828676.mp3
# 834553.mp3
# 839546.mp3
# 840775.mp3
# 840874.mp3
# 841130.mp3
# 841457.mp3
# 842823.mp3
# 845113.mp3
# 845114.mp3
# 845323.mp3
# 845399.mp3
# 845503.mp3
# 845614.mp3
# 845789.mp3
# 858068.mp3
# 860703.mp3
# 861059.mp3
# 863069.mp3
# 863076.mp3
# 863151.mp3
# 863163.mp3
# 863506.mp3
# 863696.mp3
# 871935.mp3
# 872577.mp3
# 878344.mp3
# 879381.mp3
# 879383.mp3
# 879528.mp3
# 879928.mp3
# 880693.mp3
# 881754.mp3
# 882434.mp3
# 883038.mp3
# 883813.mp3
# 892021.mp3
# 895716.mp3
# 900366.mp3
# 900978.mp3
# 901665.mp3
# 903228.mp3
# 903229.mp3
# 904547.mp3
# 904548.mp3
# 905810.mp3
# 905811.mp3
# 905812.mp3
# failed for:  ['845614.mp3', '883038.mp3']
# deleting old mp3 files
# 806090_reduced.wav
# 1  from 806090_reduced.wav
# 807305_reduced.wav
# 13  from 807305_reduced.wav
# 807982_reduced.wav
# 5  from 807982_reduced.wav
# 808862_reduced.wav
# 17  from 808862_reduced.wav
# 809722_reduced.wav
# 1  from 809722_reduced.wav
# 812093_reduced.wav
# 1  from 812093_reduced.wav
# 812094_reduced.wav
# 1  from 812094_reduced.wav
# 812095_reduced.wav
# 1  from 812095_reduced.wav
# 813162_reduced.wav
# 22  from 813162_reduced.wav
# 813506_reduced.wav
# 10  from 813506_reduced.wav
# 815975_reduced.wav
# 1  from 815975_reduced.wav
# 819044_reduced.wav
# 13  from 819044_reduced.wav
# 823988_reduced.wav
# 16  from 823988_reduced.wav
# 824055_reduced.wav
# 58  from 824055_reduced.wav
# 826610_reduced.wav
# 4  from 826610_reduced.wav
# 828673_reduced.wav
# 5  from 828673_reduced.wav
# 828675_reduced.wav
# 6  from 828675_reduced.wav
# 828676_reduced.wav
# 3  from 828676_reduced.wav
# 834553_reduced.wav
# 1  from 834553_reduced.wav
# 839546_reduced.wav
# 23  from 839546_reduced.wav
# 840775_reduced.wav
# 23  from 840775_reduced.wav
# 840874_reduced.wav
# 7  from 840874_reduced.wav
# 841130_reduced.wav
# 1  from 841130_reduced.wav
# 841457_reduced.wav
# 19  from 841457_reduced.wav
# 842823_reduced.wav
# 4  from 842823_reduced.wav
# 845113_reduced.wav
# 17  from 845113_reduced.wav
# 845114_reduced.wav
# 14  from 845114_reduced.wav
# 845323_reduced.wav
# 7  from 845323_reduced.wav
# 845399_reduced.wav
# 1  from 845399_reduced.wav
# 845503_reduced.wav
# 7  from 845503_reduced.wav
# recycling old stuff
# writing .wav files
# 808756.mp3
# 808872.mp3
# 809529.mp3
# 810103.mp3
# 816118.mp3
# 816119.mp3
# 818951.mp3
# 819364.mp3
# 820465.mp3
# 824148.mp3
# 825834.mp3
# 825928.mp3
# 826026.mp3
# 826181.mp3
# 829201.mp3
# 829337.mp3
# 832328.mp3
# 833022.mp3
# 833313.mp3
# 833448.mp3
# 833449.mp3
# 834096.mp3
# 834775.mp3
# 838663.mp3
# 839150.mp3
# 839339.mp3
# 839900.mp3
# 840591.mp3
# 840852.mp3
# 840853.mp3
# 840915.mp3
# 842372.mp3
# 843475.mp3
# 843485.mp3
# 844225.mp3
# 844244.mp3
# 845612.mp3
# 845620.mp3
# 845622.mp3
# 846055.mp3
# 855705.mp3
# 855706.mp3
# 858054.mp3
# 858545.mp3
# 860694.mp3
# 860705.mp3
# 860774.mp3
# 861055.mp3
# 861304.mp3
# 862278.mp3
# 862664.mp3
# 862666.mp3
# 862668.mp3
# 862669.mp3
# 863288.mp3
# 863693.mp3
# 863694.mp3
# 864221.mp3
# 864371.mp3
# 864561.mp3
# 864577.mp3
# 864637.mp3
# 865894.mp3
# 870638.mp3
# 871191.mp3
# 871192.mp3
# 871193.mp3
# 872288.mp3
# 872670.mp3
# 872672.mp3
# 872939.mp3
# 875657.mp3
# 875658.mp3
# 876126.mp3
# 876507.mp3
# 877979.mp3
# 878139.mp3
# 878149.mp3
# 878427.mp3
# 878431.mp3
# 878790.mp3
# 878839.mp3
# 878840.mp3
# 878843.mp3
# 878844.mp3
# 878846.mp3
# 878847.mp3
# 878849.mp3
# 878883.mp3
# 878884.mp3
# 878885.mp3
# 879266.mp3
# 879448.mp3
# 879455.mp3
# 879533.mp3
# 879612.mp3
# 881036.mp3
# 881153.mp3
# 881355.mp3
# 881390.mp3
# 881393.mp3
# 881431.mp3
# 881432.mp3
# 881521.mp3
# 881522.mp3
# 881523.mp3
# 881737.mp3
# 881746.mp3
# 881748.mp3
# 881821.mp3
# 882443.mp3
# 882480.mp3
# 883881.mp3
# 883970.mp3
# 883974.mp3
# 884151.mp3
# 884524.mp3
# 884805.mp3
# 884911.mp3
# 890369.mp3
# 890465.mp3
# 891574.mp3
# 892012.mp3
# 892138.mp3
# 892988.mp3
# 893161.mp3
# 893344.mp3
# 893840.mp3
# 894741.mp3
# 894825.mp3
# 895101.mp3
# 895102.mp3
# 895104.mp3
# 895327.mp3
# 895343.mp3
# 896426.mp3
# 896737.mp3
# 897398.mp3
# 897938.mp3
# 898175.mp3
# 898660.mp3
# 899041.mp3
# 899043.mp3
# 899526.mp3
# 900611.mp3
# 900709.mp3
# 901138.mp3
# 901278.mp3
# 901767.mp3
# 902418.mp3
# 902419.mp3
# 902431.mp3
# 902437.mp3
# 902440.mp3
# 902517.mp3
# 902811.mp3
# 902908.mp3
# 903024.mp3
# 903200.mp3
# 903393.mp3
# 904342.mp3
# 904344.mp3
# 905127.mp3
# 905537.mp3
# 905751.mp3
# 905758.mp3
# 906050.mp3
# 906247.mp3
# 906604.mp3
# 907157.mp3
# 908426.mp3
# failed for:  ['839150.mp3', '840915.mp3', '842372.mp3', '845612.mp3', '845620.mp3', '855706.mp3', '858054.mp3', '858545.mp3', '860774.mp3', '863288.mp3', '875657.mp3', '878790.mp3', '879455.mp3', '881153.mp3', '881390.mp3', '883881.mp3', '892988.mp3', '893344.mp3', '896426.mp3', '898660.mp3', '902811.mp3', '905758.mp3']
# deleting old mp3 files
# 808756_reduced.wav
# 3  from 808756_reduced.wav
# 808872_reduced.wav
# 15  from 808872_reduced.wav
# 809529_reduced.wav
# 8  from 809529_reduced.wav
# 810103_reduced.wav
# 8  from 810103_reduced.wav
# 816118_reduced.wav
# 3  from 816118_reduced.wav
# 816119_reduced.wav
# 2  from 816119_reduced.wav
# 818951_reduced.wav
# 14  from 818951_reduced.wav
# 819364_reduced.wav
# 1  from 819364_reduced.wav
# 820465_reduced.wav
# 1  from 820465_reduced.wav
# 824148_reduced.wav
# 1  from 824148_reduced.wav
# 825834_reduced.wav
# 10  from 825834_reduced.wav
# 825928_reduced.wav
# 20  from 825928_reduced.wav
# 826026_reduced.wav
# 5  from 826026_reduced.wav
# 826181_reduced.wav
# 1  from 826181_reduced.wav
# 829201_reduced.wav
# 1  from 829201_reduced.wav
# 829337_reduced.wav
# 1  from 829337_reduced.wav
# 832328_reduced.wav
# 4  from 832328_reduced.wav
# 833022_reduced.wav
# 1  from 833022_reduced.wav
# 833313_reduced.wav
# 3  from 833313_reduced.wav
# 833448_reduced.wav
# 1  from 833448_reduced.wav
# 833449_reduced.wav
# 8  from 833449_reduced.wav
# 834096_reduced.wav
# 1  from 834096_reduced.wav
# 834775_reduced.wav
# 1  from 834775_reduced.wav
# 838663_reduced.wav
# 1  from 838663_reduced.wav
# 839150_reduced.wav
# 1  from 839150_reduced.wav
# 839339_reduced.wav
# 1  from 839339_reduced.wav
# 839900_reduced.wav
# 1  from 839900_reduced.wav
# 840591_reduced.wav
# 1  from 840591_reduced.wav
# 840852_reduced.wav
# 22  from 840852_reduced.wav
# 840853_reduced.wav
# 5  from 840853_reduced.wav
# 840915_reduced.wav
# 1  from 840915_reduced.wav
# 842372_reduced.wav
# 5  from 842372_reduced.wav
# 843475_reduced.wav
# 1  from 843475_reduced.wav
# 843485_reduced.wav
# 1  from 843485_reduced.wav
# 844225_reduced.wav
# 1  from 844225_reduced.wav
# 844244_reduced.wav
# 3  from 844244_reduced.wav
# 845612_reduced.wav
# 4  from 845612_reduced.wav
# 845620_reduced.wav
# 1  from 845620_reduced.wav
# 845622_reduced.wav
# 1  from 845622_reduced.wav
# 846055_reduced.wav
# 1  from 846055_reduced.wav
# 855705_reduced.wav
# 1  from 855705_reduced.wav
# 855706_reduced.wav
# 6  from 855706_reduced.wav
# 858054_reduced.wav
# 7  from 858054_reduced.wav
# 858545_reduced.wav
# 5  from 858545_reduced.wav
# 860694_reduced.wav
# 3  from 860694_reduced.wav
# 860705_reduced.wav
# 1  from 860705_reduced.wav
# 860774_reduced.wav
# 3  from 860774_reduced.wav
# 861055_reduced.wav
# 1  from 861055_reduced.wav
# 861304_reduced.wav
# 1  from 861304_reduced.wav
# 862278_reduced.wav
# 1  from 862278_reduced.wav
# 862664_reduced.wav
# 1  from 862664_reduced.wav
# 862666_reduced.wav
# 1  from 862666_reduced.wav
# 862668_reduced.wav
# 1  from 862668_reduced.wav
# 862669_reduced.wav
# 1  from 862669_reduced.wav
# 863288_reduced.wav
# 11  from 863288_reduced.wav
# 863693_reduced.wav
# 1  from 863693_reduced.wav
# 863694_reduced.wav
# 1  from 863694_reduced.wav
# 864221_reduced.wav
# 1  from 864221_reduced.wav
# 864371_reduced.wav
# 1  from 864371_reduced.wav
# 864561_reduced.wav
# 1  from 864561_reduced.wav
# 864577_reduced.wav
# 1  from 864577_reduced.wav
# 864637_reduced.wav
# 2  from 864637_reduced.wav
# 865894_reduced.wav
# 1  from 865894_reduced.wav
# 870638_reduced.wav
# 1  from 870638_reduced.wav
# 871191_reduced.wav
# 3  from 871191_reduced.wav
# 871192_reduced.wav
# 4  from 871192_reduced.wav
# 871193_reduced.wav
# 6  from 871193_reduced.wav
# 872288_reduced.wav
# 1  from 872288_reduced.wav
# 872670_reduced.wav
# 4  from 872670_reduced.wav
# 872672_reduced.wav
# 4  from 872672_reduced.wav
# 872939_reduced.wav
# 1  from 872939_reduced.wav
# 875657_reduced.wav
# 1  from 875657_reduced.wav
# 875658_reduced.wav
# 1  from 875658_reduced.wav
# 876126_reduced.wav
# 1  from 876126_reduced.wav
# 876507_reduced.wav
# 1  from 876507_reduced.wav
# 877979_reduced.wav
# 1  from 877979_reduced.wav
# 878139_reduced.wav
# 2  from 878139_reduced.wav
# 878149_reduced.wav
# 5  from 878149_reduced.wav
# 878427_reduced.wav
# 3  from 878427_reduced.wav
# 878431_reduced.wav
# 1  from 878431_reduced.wav
# 878790_reduced.wav
# 10  from 878790_reduced.wav
# 878839_reduced.wav
# 1  from 878839_reduced.wav
# 878840_reduced.wav
# 1  from 878840_reduced.wav
# 878843_reduced.wav
# 1  from 878843_reduced.wav
# 878844_reduced.wav
# 1  from 878844_reduced.wav
# 878846_reduced.wav
# 1  from 878846_reduced.wav
# 878847_reduced.wav
# 1  from 878847_reduced.wav
# 878849_reduced.wav
# 1  from 878849_reduced.wav
# 878883_reduced.wav
# 1  from 878883_reduced.wav
# 878884_reduced.wav
# 1  from 878884_reduced.wav
# 878885_reduced.wav
# 1  from 878885_reduced.wav
# 879266_reduced.wav
# 1  from 879266_reduced.wav
# 879448_reduced.wav
# 4  from 879448_reduced.wav
# 879455_reduced.wav
# 2  from 879455_reduced.wav
# 879533_reduced.wav
# 1  from 879533_reduced.wav
# 879612_reduced.wav
# 1  from 879612_reduced.wav
# 881036_reduced.wav
# 3  from 881036_reduced.wav
# 881153_reduced.wav
# 10  from 881153_reduced.wav
# 881355_reduced.wav
# 1  from 881355_reduced.wav
# 881390_reduced.wav
# 3  from 881390_reduced.wav
# recycling old stuff
# writing .wav files
# 807286.mp3
# 814631.mp3
# 824502.mp3
# 826553.mp3
# 833263.mp3
# 839413.mp3
# 864286.mp3
# 875258.mp3
# 876580.mp3
# 878172.mp3
# 878175.mp3
# 878176.mp3
# 878178.mp3
# 878180.mp3
# 878181.mp3
# 878183.mp3
# 878185.mp3
# 878788.mp3
# 894876.mp3
# failed for:  ['876580.mp3', '878181.mp3', '878788.mp3', '894876.mp3']
# deleting old mp3 files
# 807286_reduced.wav
# 1  from 807286_reduced.wav
# 814631_reduced.wav
# 2  from 814631_reduced.wav
# 824502_reduced.wav
# 3  from 824502_reduced.wav
# 826553_reduced.wav
# 2  from 826553_reduced.wav
# 833263_reduced.wav
# 1  from 833263_reduced.wav
# 839413_reduced.wav
# 1  from 839413_reduced.wav
# 864286_reduced.wav
# 1  from 864286_reduced.wav
# 875258_reduced.wav
# 1  from 875258_reduced.wav
# 876580_reduced.wav
# 1  from 876580_reduced.wav
# 878172_reduced.wav
# 8  from 878172_reduced.wav
# 878175_reduced.wav
# 9  from 878175_reduced.wav
# 878176_reduced.wav
# 1  from 878176_reduced.wav
# 878178_reduced.wav
# 2  from 878178_reduced.wav
# 878180_reduced.wav
# 1  from 878180_reduced.wav
# 878181_reduced.wav
# 1  from 878181_reduced.wav
# 878183_reduced.wav
# 1  from 878183_reduced.wav
# 878185_reduced.wav
# 3  from 878185_reduced.wav
# 878788_reduced.wav
# 1  from 878788_reduced.wav
# 894876_reduced.wav
# 15  from 894876_reduced.wav
# recycling old stuff
# writing .wav files
# 806713.mp3
# 806714.mp3
# 806715.mp3
# 806716.mp3
# 806717.mp3
# 808335.mp3
# 808336.mp3
# 808573.mp3
# 808936.mp3
# 809203.mp3
# 811634.mp3
# 811636.mp3
# 812026.mp3
# 812395.mp3
# 814683.mp3
# 814851.mp3
# 815109.mp3
# 815477.mp3
# 815532.mp3
# 816843.mp3
# 817298.mp3
# 817305.mp3
# 817307.mp3
# 817485.mp3
# 818666.mp3
# 818671.mp3
# 818676.mp3
# 819523.mp3
# 819525.mp3
# 819683.mp3
# 819764.mp3
# 820136.mp3
# 820196.mp3
# 820333.mp3
# 820340.mp3
# 820341.mp3
# 820872.mp3
# 823481.mp3
# 830448.mp3
# 830552.mp3
# 831916.mp3
# 832020.mp3
# 835058.mp3
# 835060.mp3
# 835064.mp3
# 835066.mp3
# 835068.mp3
# 835083.mp3
# 835085.mp3
# 837455.mp3
# 841356.mp3
# 842414.mp3
# 843321.mp3
# 843477.mp3
# 844513.mp3
# 844516.mp3
# 844925.mp3
# 845914.mp3
# 846053.mp3
# 846054.mp3
# 854595.mp3
# 856957.mp3
# 859067.mp3
# 861140.mp3
# 861200.mp3
# 861693.mp3
# 863158.mp3
# 863218.mp3
# 863219.mp3
# 863222.mp3
# 864446.mp3
# 864450.mp3
# 865973.mp3
# 871788.mp3
# 871863.mp3
# 871992.mp3
# 872115.mp3
# 872123.mp3
# 875260.mp3
# 879927.mp3
# 881413.mp3
# 881425.mp3
# 881740.mp3
# 881741.mp3
# 882124.mp3
# 890413.mp3
# 893164.mp3
# 895722.mp3
# 896492.mp3
# 896493.mp3
# 897181.mp3
# 897658.mp3
# 897743.mp3
# 898521.mp3
# 898810.mp3
# 899351.mp3
# 901049.mp3
# 901050.mp3
# 901051.mp3
# 901052.mp3
# 901053.mp3
# 901054.mp3
# 901055.mp3
# 901056.mp3
# 901057.mp3
# 901058.mp3
# 901059.mp3
# 901060.mp3
# 906170.mp3
# 906528.mp3
# 906529.mp3
# 906530.mp3
# 906531.mp3
# 906564.mp3
# 907848.mp3
# 908354.mp3
# 908403.mp3
# 908816.mp3
# failed for:  ['864446.mp3', '864450.mp3', '908816.mp3']
# deleting old mp3 files
# 806713_reduced.wav
# 28  from 806713_reduced.wav
# 806714_reduced.wav
# 32  from 806714_reduced.wav
# 806715_reduced.wav
# 25  from 806715_reduced.wav
# 806716_reduced.wav
# 15  from 806716_reduced.wav
# 806717_reduced.wav
# 26  from 806717_reduced.wav
# 808335_reduced.wav
# 1  from 808335_reduced.wav
# 808336_reduced.wav
# 1  from 808336_reduced.wav
# 808573_reduced.wav
# 8  from 808573_reduced.wav
# 808936_reduced.wav
# 1  from 808936_reduced.wav
# 809203_reduced.wav
# 9  from 809203_reduced.wav
# 811634_reduced.wav
# 1  from 811634_reduced.wav
# 811636_reduced.wav
# 1  from 811636_reduced.wav
# 812026_reduced.wav
# 9  from 812026_reduced.wav
# 812395_reduced.wav
# 16  from 812395_reduced.wav
# 814683_reduced.wav
# 16  from 814683_reduced.wav
# 814851_reduced.wav
# 24  from 814851_reduced.wav
# 815109_reduced.wav
# 34  from 815109_reduced.wav
# 815477_reduced.wav
# 27  from 815477_reduced.wav
# 815532_reduced.wav
# 1  from 815532_reduced.wav
# 816843_reduced.wav
# 1  from 816843_reduced.wav
# 817298_reduced.wav
# 32  from 817298_reduced.wav
# recycling old stuff
# writing .wav files
# 829673.mp3
# 843754.mp3
# 856599.mp3
# 862521.mp3
# 863045.mp3
# 865915.mp3
# 896643.mp3
# 897905.mp3
# 898000.mp3
# 898080.mp3
# 898805.mp3
# failed for:  ['898000.mp3']
# deleting old mp3 files
# C:\dumi\bird_reco\.venv\lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=576
#   warnings.warn(
# 829673_reduced.wav
# 4  from 829673_reduced.wav
# 843754_reduced.wav
# 1  from 843754_reduced.wav
# 856599_reduced.wav
# 6  from 856599_reduced.wav
# 862521_reduced.wav
# 3  from 862521_reduced.wav
# 863045_reduced.wav
# 2  from 863045_reduced.wav
# 865915_reduced.wav
# 2  from 865915_reduced.wav
# 896643_reduced.wav
# 1  from 896643_reduced.wav
# 897905_reduced.wav
# 1  from 897905_reduced.wav
# 898000_reduced.wav
# 6  from 898000_reduced.wav
# 898080_reduced.wav
# 1  from 898080_reduced.wav
# 898805_reduced.wav
# 1  from 898805_reduced.wav
# recycling old stuff
# writing .wav files
# 806270.mp3
# 806271.mp3
# 806276.mp3
# 806928.mp3
# 807703.mp3
# 811588.mp3
# 816534.mp3
# 817707.mp3
# 819388.mp3
# 819392.mp3
# 819475.mp3
# 822090.mp3
# 822483.mp3
# 822523.mp3
# 823685.mp3
# 826797.mp3
# 828279.mp3
# 830604.mp3
# 830610.mp3
# 831097.mp3
# 831259.mp3
# 831928.mp3
# 831929.mp3
# 831930.mp3
# 831931.mp3
# 832280.mp3
# 832427.mp3
# 832749.mp3
# 833311.mp3
# 833319.mp3
# 833646.mp3
# 834350.mp3
# 835123.mp3
# 835140.mp3
# 835308.mp3
# 836034.mp3
# 838272.mp3
# 839040.mp3
# 839042.mp3
# 840682.mp3
# 841069.mp3
# 841227.mp3
# 841228.mp3
# 844245.mp3
# 844529.mp3
# 845653.mp3
# 855686.mp3
# 856217.mp3
# 856324.mp3
# 858101.mp3
# 858102.mp3
# 860287.mp3
# 863733.mp3
# 863734.mp3
# 865914.mp3
# 871603.mp3
# 874584.mp3
# 877902.mp3
# 878801.mp3
# 878949.mp3
# 881789.mp3
# 881807.mp3
# 881809.mp3
# 881811.mp3
# 883341.mp3
# 883633.mp3
# 884120.mp3
# 884360.mp3
# 884477.mp3
# 884844.mp3
# 884845.mp3
# 890052.mp3
# 891097.mp3
# 891502.mp3
# 891503.mp3
# 891504.mp3
# 893509.mp3
# 894405.mp3
# 894724.mp3
# 894726.mp3
# 894873.mp3
# 896595.mp3
# 897652.mp3
# 897750.mp3
# 900408.mp3
# 902464.mp3
# 902467.mp3
# 902468.mp3
# 903160.mp3
# 903550.mp3
# 904065.mp3
# 904208.mp3
# failed for:  ['807703.mp3', '833646.mp3', '856217.mp3', '877902.mp3', '878949.mp3', '884477.mp3', '894873.mp3']
# deleting old mp3 files
# 806270_reduced.wav
# 8  from 806270_reduced.wav
# 806271_reduced.wav
# 7  from 806271_reduced.wav
# 806276_reduced.wav
# 1  from 806276_reduced.wav
# 806928_reduced.wav
# 1  from 806928_reduced.wav
# 807703_reduced.wav
# 3  from 807703_reduced.wav
# 811588_reduced.wav
# 38  from 811588_reduced.wav
# 816534_reduced.wav
# 104  from 816534_reduced.wav
# 817707_reduced.wav
# 8  from 817707_reduced.wav
# 819388_reduced.wav
# 13  from 819388_reduced.wav
# 819392_reduced.wav
# 4  from 819392_reduced.wav
# 819475_reduced.wav
# 19  from 819475_reduced.wav
# 822090_reduced.wav
# 17  from 822090_reduced.wav
# 822483_reduced.wav
# 1  from 822483_reduced.wav
# 822523_reduced.wav
# 1  from 822523_reduced.wav
# 823685_reduced.wav
# 4  from 823685_reduced.wav
# 826797_reduced.wav
# 7  from 826797_reduced.wav
# 828279_reduced.wav
# 9  from 828279_reduced.wav
# 830604_reduced.wav
# 43  from 830604_reduced.wav
# 830610_reduced.wav
# 18  from 830610_reduced.wav
# recycling old stuff
# writing .wav files
# 808720.mp3
# 809072.mp3
# 809073.mp3
# 809074.mp3
# 809075.mp3
# 809554.mp3
# 812111.mp3
# 814636.mp3
# 814637.mp3
# 816845.mp3
# 819693.mp3
# 820050.mp3
# 820463.mp3
# 821167.mp3
# 821933.mp3
# 822478.mp3
# 824062.mp3
# 828529.mp3
# 828802.mp3
# 830959.mp3
# 836412.mp3
# 836413.mp3
# 836414.mp3
# 838030.mp3
# 838032.mp3
# 838989.mp3
# 839248.mp3
# 839527.mp3
# 840494.mp3
# 841414.mp3
# 842209.mp3
# 842389.mp3
# 843576.mp3
# 844080.mp3
# 844453.mp3
# 855426.mp3
# 855547.mp3
# 855676.mp3
# 855677.mp3
# 858300.mp3
# 861760.mp3
# 862133.mp3
# 863229.mp3
# 863515.mp3
# 871865.mp3
# 871866.mp3
# 872510.mp3
# 872963.mp3
# 876887.mp3
# 878526.mp3
# 878868.mp3
# 879351.mp3
# 879895.mp3
# 881422.mp3
# 883303.mp3
# 890519.mp3
# 890853.mp3
# 890856.mp3
# 891470.mp3
# 892909.mp3
# 894167.mp3
# 894806.mp3
# 896727.mp3
# 897040.mp3
# 898228.mp3
# 899492.mp3
# 904918.mp3
# 905114.mp3
# 905913.mp3
# 908799.mp3
# failed for:  ['828529.mp3', '844453.mp3', '863515.mp3', '894806.mp3']
# deleting old mp3 files
# 808720_reduced.wav
# 11  from 808720_reduced.wav
# 809072_reduced.wav
# 1  from 809072_reduced.wav
# 809073_reduced.wav
# 1  from 809073_reduced.wav
# 809074_reduced.wav
# 1  from 809074_reduced.wav
# 809075_reduced.wav
# 1  from 809075_reduced.wav
# 809554_reduced.wav
# 1  from 809554_reduced.wav
# 812111_reduced.wav
# 1  from 812111_reduced.wav
# 814636_reduced.wav
# 35  from 814636_reduced.wav
# 814637_reduced.wav
# 15  from 814637_reduced.wav
# 816845_reduced.wav
# 1  from 816845_reduced.wav
# 819693_reduced.wav
# 1  from 819693_reduced.wav
# 820050_reduced.wav
# 51  from 820050_reduced.wav
# 820463_reduced.wav
# 1  from 820463_reduced.wav
# 821167_reduced.wav
# 8  from 821167_reduced.wav
# 821933_reduced.wav
# 17  from 821933_reduced.wav
# 822478_reduced.wav
# 1  from 822478_reduced.wav
# 824062_reduced.wav
# 11  from 824062_reduced.wav
# 828529_reduced.wav
# 49  from 828529_reduced.wav
# 828802_reduced.wav
# 11  from 828802_reduced.wav
# 830959_reduced.wav
# 1  from 830959_reduced.wav
# 836412_reduced.wav
# 29  from 836412_reduced.wav
# 836413_reduced.wav
# 55  from 836413_reduced.wav
# recycling old stuff
# writing .wav files
# 809231.mp3
# 813321.mp3
# 813322.mp3
# 813323.mp3
# 823996.mp3
# 823997.mp3
# 828751.mp3
# 832365.mp3
# 843653.mp3
# 845012.mp3
# 855340.mp3
# 855453.mp3
# 855457.mp3
# 862836.mp3
# 863513.mp3
# 871443.mp3
# 872925.mp3
# 872926.mp3
# 872927.mp3
# 878692.mp3
# 879800.mp3
# 883859.mp3
# 884118.mp3
# 891241.mp3
# 898571.mp3
# 905054.mp3
# 908858.mp3
# failed for:  ['855453.mp3', '855457.mp3', '878692.mp3']
# deleting old mp3 files
# 809231_reduced.wav
# 10  from 809231_reduced.wav
# 813321_reduced.wav
# 7  from 813321_reduced.wav
# 813322_reduced.wav
# 13  from 813322_reduced.wav
# 813323_reduced.wav
# 17  from 813323_reduced.wav
# 823996_reduced.wav
# 27  from 823996_reduced.wav
# 823997_reduced.wav
# 25  from 823997_reduced.wav
# 828751_reduced.wav
# 14  from 828751_reduced.wav
# 832365_reduced.wav
# 1  from 832365_reduced.wav
# 843653_reduced.wav
# 1  from 843653_reduced.wav
# 845012_reduced.wav
# 12  from 845012_reduced.wav
# 855340_reduced.wav
# 1  from 855340_reduced.wav
# 855453_reduced.wav
# 2  from 855453_reduced.wav
# 855457_reduced.wav
# 3  from 855457_reduced.wav
# 862836_reduced.wav
# 13  from 862836_reduced.wav
# 863513_reduced.wav
# 1  from 863513_reduced.wav
# 871443_reduced.wav
# 26  from 871443_reduced.wav
# 872925_reduced.wav
# 1  from 872925_reduced.wav
# 872926_reduced.wav
# 1  from 872926_reduced.wav
# 872927_reduced.wav
# 1  from 872927_reduced.wav
# 878692_reduced.wav
# 3  from 878692_reduced.wav
# 879800_reduced.wav
# 10  from 879800_reduced.wav
# 883859_reduced.wav
# 22  from 883859_reduced.wav
# 884118_reduced.wav
# 7  from 884118_reduced.wav
# 891241_reduced.wav
# 2  from 891241_reduced.wav
# 898571_reduced.wav
# 33  from 898571_reduced.wav
# 905054_reduced.wav
# 14  from 905054_reduced.wav
# 908858_reduced.wav
# 27  from 908858_reduced.wav
# recycling old stuff
# writing .wav files
# 809781.mp3
# 822174.mp3
# 859056.mp3
# 862891.mp3
# 870796.mp3
# 872066.mp3
# 872074.mp3
# 879462.mp3
# 880744.mp3
# 881050.mp3
# 884134.mp3
# failed for:  []
# deleting old mp3 files
# 809781_reduced.wav
# 30  from 809781_reduced.wav
# 822174_reduced.wav
# 1  from 822174_reduced.wav
# 859056_reduced.wav
# 1  from 859056_reduced.wav
# 862891_reduced.wav
# 1  from 862891_reduced.wav
# 870796_reduced.wav
# 3  from 870796_reduced.wav
# 872066_reduced.wav
# 1  from 872066_reduced.wav
# 872074_reduced.wav
# 1  from 872074_reduced.wav
# 879462_reduced.wav
# 14  from 879462_reduced.wav
# 880744_reduced.wav
# 1  from 880744_reduced.wav
# 881050_reduced.wav
# 1  from 881050_reduced.wav
# 884134_reduced.wav
# 1  from 884134_reduced.wav
# recycling old stuff
# writing .wav files
# 834612.mp3
# 834617.mp3
# 838126.mp3
# 838128.mp3
# 841670.mp3
# 861332.mp3
# 861344.mp3
# 861369.mp3
# 861371.mp3
# 861384.mp3
# 862166.mp3
# 871049.mp3
# 871290.mp3
# 879576.mp3
# 881453.mp3
# 881858.mp3
# 882091.mp3
# 890299.mp3
# 893492.mp3
# 894771.mp3
# 894929.mp3
# 902525.mp3
# 904993.mp3
# failed for:  ['862166.mp3', '882091.mp3', '893492.mp3']
# deleting old mp3 files
# 834612_reduced.wav
# 87  from 834612_reduced.wav
# 834617_reduced.wav
# 1  from 834617_reduced.wav
# 838126_reduced.wav
# 1  from 838126_reduced.wav
# 838128_reduced.wav
# 1  from 838128_reduced.wav
# 841670_reduced.wav
# 2  from 841670_reduced.wav
# 861332_reduced.wav
# 1  from 861332_reduced.wav
# 861344_reduced.wav
# 1  from 861344_reduced.wav
# 861369_reduced.wav
# 1  from 861369_reduced.wav
# 861371_reduced.wav
# 1  from 861371_reduced.wav
# 861384_reduced.wav
# 4  from 861384_reduced.wav
# 862166_reduced.wav
# 10  from 862166_reduced.wav
# 871049_reduced.wav
# 5  from 871049_reduced.wav
# 871290_reduced.wav
# 6  from 871290_reduced.wav
# 879576_reduced.wav
# 1  from 879576_reduced.wav
# 881453_reduced.wav
# 1  from 881453_reduced.wav
# 881858_reduced.wav
# 1  from 881858_reduced.wav
# 882091_reduced.wav
# 1  from 882091_reduced.wav
# 890299_reduced.wav
# 1  from 890299_reduced.wav
# 893492_reduced.wav
# 1  from 893492_reduced.wav
# 894771_reduced.wav
# 1  from 894771_reduced.wav
# 894929_reduced.wav
# 1  from 894929_reduced.wav
# 902525_reduced.wav
# 14  from 902525_reduced.wav
# 904993_reduced.wav
# 21  from 904993_reduced.wav
# recycling old stuff
# writing .wav files
# 807367.mp3
# 809207.mp3
# 809523.mp3
# 809934.mp3
# 813572.mp3
# 813881.mp3
# 814144.mp3
# 814640.mp3
# 814641.mp3
# 814642.mp3
# 814643.mp3
# 814644.mp3
# 814645.mp3
# 814646.mp3
# 814648.mp3
# 814649.mp3
# 814650.mp3
# 814651.mp3
# 814652.mp3
# 814653.mp3
# 815513.mp3
# 819371.mp3
# 820725.mp3
# 822131.mp3
# 822524.mp3
# 823479.mp3
# 832357.mp3
# 832360.mp3
# 833576.mp3
# 836056.mp3
# 837030.mp3
# 840566.mp3
# 840567.mp3
# 840678.mp3
# 840679.mp3
# 840680.mp3
# 856274.mp3
# 858776.mp3
# 863126.mp3
# 863135.mp3
# 863136.mp3
# 893709.mp3
# 896245.mp3
# 899188.mp3
# 899193.mp3
# 899199.mp3
# 899206.mp3
# 899207.mp3
# 899208.mp3
# 899508.mp3
# 900352.mp3
# 902421.mp3
# 904773.mp3
# failed for:  ['807367.mp3', '809934.mp3', '832360.mp3', '904773.mp3']
# deleting old mp3 files
# 807367_reduced.wav
# 12  from 807367_reduced.wav
# 809207_reduced.wav
# 14  from 809207_reduced.wav
# 809523_reduced.wav
# 1  from 809523_reduced.wav
# 809934_reduced.wav
# 2  from 809934_reduced.wav
# 813572_reduced.wav
# 6  from 813572_reduced.wav
# 813881_reduced.wav
# 16  from 813881_reduced.wav
# 814144_reduced.wav
# 8  from 814144_reduced.wav
# 814640_reduced.wav
# 19  from 814640_reduced.wav
# 814641_reduced.wav
# 6  from 814641_reduced.wav
# 814642_reduced.wav
# 3  from 814642_reduced.wav
# 814643_reduced.wav
# 4  from 814643_reduced.wav
# 814644_reduced.wav

# %%
import os
from matplotlib import pyplot as plt
import tensorflow as tf
import tensorflow_io as tfio

# %%
def load_wav_16k_mono(filename):
    # Load encoded wav file
    file_contents = tf.io.read_file(filename)
    # Decode wav (tensors by channels)
    wav, sample_rate = tf.audio.decode_wav(file_contents, desired_channels=1, desired_samples=48000)
    # Removes trailing axis
    wav = tf.squeeze(wav, axis=-1)
    sample_rate = tf.cast(sample_rate, dtype=tf.int64)
    # Goes from 44100Hz to 16000hz - amplitude of the audio signal
    wav = tfio.audio.resample(wav, rate_in=sample_rate, rate_out=16000)
    return wav

# %%
dirs = dict()

bird_labels = {bird: i for i, bird in enumerate(birds)}

for bird in birds:
    dirs[bird] = os.path.join('..', 'sounds', bird, 'splits')
    
files = dict()
for bird in birds:
    files[bird] = tf.data.Dataset.list_files(dirs[bird] + "\*.wav")
    
bird_data = dict()

for bird in birds:
    bird_label = bird_labels[bird]
    dataset_length = len(list(files[bird].as_numpy_iterator()))
    labels_dataset = tf.data.Dataset.from_tensor_slices(tf.ones(dataset_length) * bird_label)
    bird_data[bird] = tf.data.Dataset.zip((files[bird], labels_dataset))
    
data = None
for bird in birds:
    if data is None:
        data = bird_data[bird]
    else:
        data = data.concatenate(bird_data[bird])

# %%
lengths = []
skipped = 0

for file in os.listdir(house_sparrows_dir):
    try:
        tensor_wave = load_wav_16k_mono(os.path.join(house_sparrows_dir, file))
        lengths.append(len(tensor_wave))
    except Exception as e:
        skipped += 1
        print(file)
        pass
print("done")

# %%
# tf.math.reduce_mean(lengths)
# tf.math.reduce_min(lengths)

# %%
def preprocess(file_path, label):
    wav = load_wav_16k_mono(file_path)
    wav = wav[:48000]
    zero_padding = tf.zeros([48000] - tf.shape(wav), dtype=tf.float32)
    wav = tf.concat([zero_padding, wav], 0)
    spectrogram = tf.signal.stft(wav, frame_length=320, frame_step=32)
    spectrogram = tf.abs(spectrogram)
    spectrogram = tf.expand_dims(spectrogram, axis=2)
    return spectrogram, label

# %%
data = data.map(preprocess)
data = data.cache()
data = data.shuffle(buffer_size=1000)
data = data.batch(16)
data = data.prefetch(8)
data

# %%
train = data.take(36)
test = data.skip(36).take(15)

# %%
samples, labels = train.as_numpy_iterator().next()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten

# %%
model = Sequential()
model.add(Conv2D(16, (3,3), activation="relu", input_shape=(1491, 257,1)))
model.add(Conv2D(16, (3,3), activation="relu"))
model.add(Flatten())
model.add(Dense(128, activation="relu"))
model.add(Dense(1, activation="sigmoid"))

# %%
model.compile('Adam', loss='BinaryCrossentropy', metrics=[tf.keras.metrics.Recall(),tf.keras.metrics.Precision()])

# %%
hist = model.fit(train, epochs=1, validation_data=test)

# %%
plt.title('Loss')
plt.plot(hist.history['loss'], 'r')
plt.plot(hist.history['val_loss'], 'b')
plt.show()

# %%
plt.title('Precision')
plt.plot(hist.history['precision'], 'r')
plt.plot(hist.history['val_precision'], 'b')
plt.show()

# %%
plt.title('Recall')
plt.plot(hist.history['recall'], 'r')
plt.plot(hist.history['val_recall'], 'b')
plt.show()

# %%
X_test, y_test = test.as_numpy_iterator().next()
yhat = model.predict(X_test)

# %%
yhat = [1 if prediction > 0.5 else 0 for prediction in yhat]
yhat

# %%
def load_mp3_16k_mono(filename):
    res = tfio.audio.AudioIOTensor(filename)
    tensor = res.to_tensor()
    tensor = tf.math.reduce_sum(tensor, axis=1)/2

    sample_rate = res.rate
    sample_rate = tf.cast(sample_rate, dtype=tf.int64)
    wav = tfio.audio.resample(tensor, rate_in=sample_rate, rate_out=160000)
    return wav
